# %%
import numpy as np
import copy as cp
import random
from graphics import *
from numpy import *
from datetime import datetime, date, time

# %%
class tree:
    def __init__(self, data = 0, N = None, l = None, lm = None, rm = None, r = None, flag = 0):
        self.flag = flag
        self.data = data
        self.N = N
        self.l  = l 
        self.lm = lm
        self.rm = rm
        self.r  = r
        

    def create_tree (self, x, y): 
        n0=0;n1=0;n2=0;n3=0
        n_0 = [];n_1 = [];n_2 = [];n_3 = []

        self.l = None
        self.lm = None
        self.rm = None
        self.r = None

        if self.N[1] > 1:    
            xm = self.N[2][0]
            ym = self.N[2][1]
            
            for j in range (0,self.N[1]):
                i = self.data[j]
                if x[i] < xm:    
                    if y[i] < ym:
                        n_0.append(i)
                        n0=n0+1
                    else:
                        n_1.append(i)
                        n1=n1+1
                else:
                    if y[i] >= ym:
                        n_2.append(i)
                        n2=n2+1
                    else:
                        n_3.append(i)
                        n3=n3+1
                        
            if n0>0:
                self.l = tree(n_0,[0+self.N[0], n0, None, None])
            if n1>0:
                self.lm = tree(n_1, [n0+self.N[0], n1, None, None])
            if n2>0:
                self.rm = tree(n_2, [n0+n1+self.N[0], n2, None, None])
            if n3>0:
                self.r = tree(n_3, [n0+n1+n2+self.N[0], n3, None, None])

# %%
def mid (t, x,y):    
    if t.N[2] == None:
        t.N[2] = [0,0]            
        for i in range(0, t.N[1]):
            t.N[2][0] = t.N[2][0] + x[t.data[i]]
            t.N[2][1] = t.N[2][1] + y[t.data[i]]
        t.N[2][0] = t.N[2][0]/t.N[1]
        t.N[2][1] = t.N[2][1]/t.N[1]
        
    if (t.N[3] == None):
        xmax = x[t.data[0]]; xmin = x[t.data[0]]; ymax = y[t.data[0]]; ymin = y[t.data[0]];
        for j in range (0,t.N[1]):
            i = t.data[j]
            xmax = max(x[i],xmax)
            ymax = max(y[i],ymax)
            xmin = min(x[i],xmin)
            ymin = min(y[i],ymin)
        t.N[3] = [xmax, ymax, xmin, ymin]
    return t.N

# %%
def count_svd (R, V, eps):
    B = np.zeros((R.N[1], V.N[1]))
    for i in range (0, R.N[1]):
        for j in range (0, V.N[1]):
            lenght = ((x1[R.data[i]]-x2[V.data[j]])**2+(y1[R.data[i]]-y2[V.data[j]])**2)**0.5
            if lenght <> 0:
                B[i][j] = 1/lenght
            else:
                B[i][j] = 0
                
    U,s,V = np.linalg.svd(B)
#    X = usual_A

    summ_s = sum(s)
    summ_1 = 0.
#    eps = 0.005
    k = len(s)-1
    for i in range (0, len(s)):
        if summ_1/summ_s<=eps**2:
            k = i
            summ_1 = summ_1 +s[-k]


    s = s[0:k+1]

    U1 = np.zeros((U.shape[0], k+1))
    for i in range(0,U.shape[0]):
        for j in range (0,k+1):
            U1[i][j]=U[i][j]
    U = U1
    V = V[0:k+1][:]

    #S = np.zeros((U.shape[1], V.shape[0]))
    #S[:s.shape[0], :s.shape[0]] = np.diag(s)

    #m = np.dot(np.dot(U,S),V)

    #print norm_ff(np.dot(X,x), np.dot(m,x))
    
    
    return U,s,V

# %%
j = array([[ 0.76003098, -0.64988684, 0], [ 0.64988684,  0.76003098, 3]])#array([[ 0.,  1.],       [ 2.,  3.]])
j[1][0:1]
# Out:
# array([ 0.64988684])

# %%
X = usual_A

summ_s = sum(s)
summ_1 = 0.

n = 0
eps = 0.005

for i in range (0, len(s)):
    if summ_1/summ_s<eps**2:
        k = len(s)-1-i
        summ_1 = summ_1 +s[k]


s = s[0:k+1]

U1 = np.zeros((U.shape[0], k+1))
for i in range(0,U.shape[0]):
    for j in range (0,k+1):
        U1[i][j]=U[i][j]
U = U1
V = V[0:k+1][:]

S = np.zeros((U.shape[1], V.shape[0]))
S[:s.shape[0], :s.shape[0]] = np.diag(s)

m = np.dot(np.dot(U,S),V)

print norm_ff(np.dot(X,x), np.dot(m,x))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-148-62e865a56c37> in <module>()
#       1 X = usual_A
#       2
# ----> 3 summ_s = sum(s)
#       4 summ_1 = 0.
#       5
#
# NameError: name 's' is not defined

# %%
def pre_count_A (R, V):
    R.N = mid(R, x1, y1)
    V.N = mid(V, x2, y2)

    lenghtR = ((R.N[3][0] - R.N[3][2])**2 + (R.N[3][1] - R.N[3][3])**2)**0.5
    lenghtV = ((V.N[3][0] - V.N[3][2])**2 + (V.N[3][1] - V.N[3][3])**2)**0.5

    lenght = ((R.N[2][0] - V.N[2][0])**2 + (R.N[2][1] - V.N[2][1])**2)**0.5

    if (max(lenghtR, lenghtV)>=lenght):
        if(R.l==None)&(R.lm==None)&(R.rm==None)&(R.r==None):
            R.create_tree(x1, y1)
        if(V.l==None)&(V.lm==None)&(V.rm==None)&(V.r==None):
            V.create_tree(x2, y2)

        n_R_0 =[]; n_R_1 =[]; n_R_2 =[]; n_R_3 =[]; n_V_0 =[]; n_V_1 =[]; n_V_2 =[]; n_V_3 =[]
        
        
        if (R.N[1]>1):
            if (V.N[1]>1):
                k = 0
                if (R.l<>None):
                    if (V.l<>None):
                        pre_count_A(R.l, V.l)
                    if (V.lm<>None):
                        pre_count_A(R.l, V.lm)
                    if (V.rm<>None):
                        pre_count_A(R.l, V.rm)
                    if (V.r<>None):
                        pre_count_A(R.l, V.r)



                if (R.lm<>None):
                    if (V.l<>None):
                        pre_count_A(R.lm, V.l)
                    if (V.lm<>None):
                        pre_count_A(R.lm, V.lm)
                    if (V.rm<>None):
                        pre_count_A(R.lm, V.rm)
                    if (V.r<>None):
                        pre_count_A(R.lm, V.r)
                  
                    
                if (R.rm<>None):
                    if (V.l<>None):
                        pre_count_A(R.rm, V.l)
                    if (V.lm<>None):
                        pre_count_A(R.rm, V.lm)
                    if (V.rm<>None):
                        pre_count_A(R.rm, V.rm)
                    if (V.r<>None):
                        pre_count_A(R.rm, V.r)
                   
                    
                if (R.r<>None):
                    if (V.l<>None):
                        pre_count_A(R.r, V.l)
                    if (V.lm<>None):
                        pre_count_A(R.r, V.lm)
                    if (V.rm<>None):
                        pre_count_A(R.r, V.rm)
                    if (V.r<>None):
                        pre_count_A(R.r, V.r)
                    
            else:
               
                if (R.l<>None):
                   pre_count_A(R.l, V)
                if (R.lm<>None):
                   pre_count_A(R.lm, V)
                if (R.rm<>None):
                   pre_count_A(R.rm, V)
                if (R.r<>None):
                   pre_count_A(R.r, V)
                
        else:
            if (V.N[1]>1):
                  
                if (V.l<>None):
                   pre_count_A(R, V.l)
                if (V.lm<>None):
                   pre_count_A(R, V.lm)
                if (V.rm<>None):
                   pre_count_A(R, V.rm)
                if (V.r<>None):
                   pre_count_A(R, V.r)
                
            
        flag = 0
        if R.flag > -1:
            if (R.l<>None):
                n_R_0 = R.l.data
                flag = flag + 1
            if (R.lm<>None):
                n_R_1 = R.lm.data
                flag = flag + 1
            if (R.rm<>None):
                n_R_2 = R.rm.data
                flag = flag + 1
            if (R.r<>None):
                n_R_3 = R.r.data
                flag = flag + 1
            if flag > 0:
                R.data = n_R_0 + n_R_1 + n_R_2 + n_R_3
            R.flag = R.flag + 1
        
        
        flag = 0
        if V.flag > -1:
            if (V.l<>None):
                n_V_0 = V.l.data
                flag = flag + 1
            if (V.lm<>None):
                n_V_1 = V.lm.data
                flag = flag + 1
            if (V.rm<>None):
                n_V_2 = V.rm.data
                flag = flag + 1
            if (V.r<>None):
                n_V_3 = V.r.data
                flag = flag + 1
            if flag > 0:
                V.data = n_V_0 + n_V_1 + n_V_2 + n_V_3
            V.flag = V.flag + 1

# %%
def count_A (R, V):

    R.N = mid(R, x1, y1)
    V.N = mid(V, x2, y2)

    lenghtR = ((R.N[3][0] - R.N[3][2])**2 + (R.N[3][1] - R.N[3][3])**2)**0.5
    lenghtV = ((V.N[3][0] - V.N[3][2])**2 + (V.N[3][1] - V.N[3][3])**2)**0.5

    lenght = ((R.N[2][0] - V.N[2][0])**2 + (R.N[2][1] - V.N[2][1])**2)**0.5

    if (max(lenghtR, lenghtV)<lenght):
        
        
        A = [count_svd(R, V, 1.0)]
    else:
        A = []        
        
        if (R.N[1]>1):
            if (V.N[1]>1):
                k = 0
                if (R.l<>None):
                    A = A+[[]]
                    if (V.l<>None):
                        A[k] = A[k] + [count_A(R.l, V.l)]
                    if (V.lm<>None):
                        A[k] = A[k] + [count_A(R.l, V.lm)]
                    if (V.rm<>None):
                        A[k] = A[k] + [count_A(R.l, V.rm)]
                    if (V.r<>None):
                        A[k] = A[k] + [count_A(R.l, V.r)]
                    k = k+1


                if (R.lm<>None):
                    A = A + [[]]
                    if (V.l<>None):
                       A[k] = A[k] + [count_A(R.lm, V.l)]
                    if (V.lm<>None):
                       A[k] = A[k] + [count_A(R.lm, V.lm)]
                    if (V.rm<>None):
                       A[k] = A[k] + [count_A(R.lm, V.rm)]
                    if (V.r<>None):
                       A[k] = A[k] + [count_A(R.lm, V.r)]
                    k = k+1
                    
                if (R.rm<>None):
                    A = A + [[]]
                    if (V.l<>None):
                       A[k] = A[k] + [count_A(R.rm, V.l)]
                    if (V.lm<>None):
                       A[k] = A[k] + [count_A(R.rm, V.lm)]
                    if (V.rm<>None):
                       A[k] = A[k] + [count_A(R.rm, V.rm)]
                    if (V.r<>None):
                       A[k] = A[k] + [count_A(R.rm, V.r)]
                    k = k+1
                    
                if (R.r<>None):
                    A = A + [[]]
                    if (V.l<>None):
                       A[k] = A[k] + [count_A(R.r, V.l)]
                    if (V.lm<>None):
                       A[k] = A[k] + [count_A(R.r, V.lm)]
                    if (V.rm<>None):
                       A[k] = A[k] + [count_A(R.r, V.rm)]
                    if (V.r<>None):
                       A[k] = A[k] + [count_A(R.r, V.r)]
                    
            else:
                A = A + []
                if (R.l<>None):
                   A = A + [[count_A(R.l, V)]]
                if (R.lm<>None):
                   A = A + [[count_A(R.lm, V)]]
                if (R.rm<>None):
                   A = A + [[count_A(R.rm, V)]]
                if (R.r<>None):
                   A = A + [[count_A(R.r, V)]]
                
        else:
            if (V.N[1]>1):
                A = A + [[]]    
                if (V.l<>None):
                   A[0] = A[0] + [count_A(R, V.l)]
                if (V.lm<>None):
                   A[0] = A[0] + [count_A(R, V.lm)]
                if (V.rm<>None):
                   A[0] = A[0] + [count_A(R, V.rm)]
                if (V.r<>None):
                   A[0] = A[0] + [count_A(R, V.r)]
                
            else:
                A = [[0]]
              
    return A

# %%
def summ(a,b):
    res = []
    for i in range(0, len(a)):
        res.append(a[i]+b[i])
    return res

# %%
def dot_Mx(A, x, k):
    M = cp.deepcopy(A)
    if (type(M) == tuple):
        U, s, V = M
        S = np.zeros((U.shape[1], V.shape[0]))
        S[:s.shape[0], :s.shape[0]] = np.diag(s)
        n = V.shape[1]
        f = np.dot(np.dot(np.dot(U,S),V),x[k:k+n]).tolist()
    if M == 0:
        f = [0]
        n = 1
    if type(M) == list:
        if M == [0]:
            f = [0]
            n = 1
        if M == []:
            f = []
            n = 0
        else:            
            string = M.pop(0)
            M3 = M
            if (len(string)<>0)and(type(string)<>tuple):
                M1 = string.pop(0)
                M2 = [string]
            else:
                M1 = string
                M2 = []
            (f1, n1) = dot_Mx(M1, x, k)
            (f2, n2) = dot_Mx(M2, x, k+n1)
            (f3, n3) = dot_Mx(M3, x, k)
            
            
            if f2 <> []:
                f = summ(f1, f2)+f3
            else:
                f = f1+f3
            n = n1+n2
    return f, n

# %%
def final_dot (x):
    x_new = []
    f_true = []
    for i in range(0,nv):
        x_new.append(x[V.data[i]])
        
    f = dot_Mx(A,x_new,0)

    for i in range (0, nr):
        f_true.append(0)
    for i in range (0, nr):
        f_true[R.data[i]] = f[0][i]
    
    print size(x_new)
    
    return f_true

# %%
nr = 1000
nv = 1000
x1=[]
y1=[]
x2=[]
y2=[]
for i in range (0,nr):
    #x1.append(random.randint(10,20))
    #y1.append(random.randint(10,20))
    x1.append(random.uniform(0,1))
    y1.append(random.uniform(0,1))
for i in range (0,nv):
    #x2.append(random.randint(0,1))
    #y2.append(random.randint(0,1))
    x2.append(random.uniform(0,1))
    y2.append(random.uniform(0,1))
    
x2 = x1
y2 = y1

# %%
x=[]

for i in range (0,nv):
    x.append(i)

# %%
#R - приёмник
#V - источник
t = datetime.today()
n_r  = []
n_v  = []
for i in range (0,nr):
    n_r.append(i)
for i in range (0,nv):
    n_v.append(i)


R = tree(n_r,[0,nr, None, None])
V = tree(n_v,[0,nv, None, None])
pre_count_A(R,V)
A = count_A(R,V)
"ok"
print datetime.today() - t
# Out:
# 0:00:03.311478

# %%
x0 = 650; y0 = 650




def draw_strings(A, x, y, size_x, size_y):
    if (type(A)==list):
        n = len(A)
        if n<>0:
            hight = size_y/n
            for i in range (1, n):
                string = Line(Point(x, y+i*hight), Point(x+size_x, y+i*hight))
                string.setWidth(1)
                string.draw(win)
            for j in range (0, n):
                draw_columns(A[j], x, y+j*hight, size_x, hight)
    else:
        if A == 0:
            rectangle = Rectangle(Point(x, y), Point(x+size_x, y+size_y))
            rectangle.setFill('red')
            rectangle.draw(win)
        else:
            rectangle = Rectangle(Point(x, y), Point(x+size_x, y+size_y))
            rectangle.setFill('green')
            rectangle.draw(win)
            
    
    
def draw_columns(A, x, y, size_x, size_y):
    if type(A)==list:
        n = len(A)
        if n<>0:

            width = size_x/n
            for i in range (1, n):
                string = Line(Point(x+i*width, y), Point(x+i*width, y+size_y))
                string.setWidth(1)
                string.draw(win)
            for j in range (0, n):
                draw_strings(A[j], x+j*width, y, width, size_y)
    else:
        if A == 0:
            rectangle = Rectangle(Point(x, y), Point(x+size_x, y+size_y))
            rectangle.setFill('red')
            rectangle.draw(win)
        else:
            rectangle = Rectangle(Point(x, y), Point(x+size_x, y+size_y))
            rectangle.setFill('green')
            rectangle.draw(win)

        
win = GraphWin('A', x0, y0)


draw_strings(A, 0., 0., 650.,650.)

win.getMouse()
win.close()
# Out:
# ---------------------------------------------------------------------------
# GraphicsError                             Traceback (most recent call last)
# <ipython-input-138-fc8766d05129> in <module>()
#      53
#      54
# ---> 55 draw_strings(A, 0., 0., 650.,650.)
#      56
#      57 win.getMouse()
#
# <ipython-input-138-fc8766d05129> in draw_strings(A, x, y, size_x, size_y)
#      14                 string.draw(win)
#      15             for j in range (0, n):
# ---> 16                 draw_columns(A[j], x, y+j*hight, size_x, hight)
#      17     else:
#      18         if A == 0:
#
# <ipython-input-138-fc8766d05129> in draw_columns(A, x, y, size_x, size_y)
#      38                 string.draw(win)
#      39             for j in range (0, n):
# ---> 40                 draw_strings(A[j], x+j*width, y, width, size_y)
#      41     else:
#      42         if A == 0:
#
# <ipython-input-138-fc8766d05129> in draw_strings(A, x, y, size_x, size_y)
#      14                 string.draw(win)
#      15             for j in range (0, n):
# ---> 16                 draw_columns(A[j], x, y+j*hight, size_x, hight)
#      17     else:
#      18         if A == 0:
#
# <ipython-input-138-fc8766d05129> in draw_columns(A, x, y, size_x, size_y)
#      38                 string.draw(win)
#      39             for j in range (0, n):
# ---> 40                 draw_strings(A[j], x+j*width, y, width, size_y)
#      41     else:
#      42         if A == 0:
#
# <ipython-input-138-fc8766d05129> in draw_strings(A, x, y, size_x, size_y)
#      14                 string.draw(win)
#      15             for j in range (0, n):
# ---> 16                 draw_columns(A[j], x, y+j*hight, size_x, hight)
#      17     else:
#      18         if A == 0:
#
# <ipython-input-138-fc8766d05129> in draw_columns(A, x, y, size_x, size_y)
#      38                 string.draw(win)
#      39             for j in range (0, n):
# ---> 40                 draw_strings(A[j], x+j*width, y, width, size_y)
#      41     else:
#      42         if A == 0:
#
# <ipython-input-138-fc8766d05129> in draw_strings(A, x, y, size_x, size_y)
#      12                 string = Line(Point(x, y+i*hight), Point(x+size_x, y+i*hight))
#      13                 string.setWidth(1)
# ---> 14                 string.draw(win)
#      15             for j in range (0, n):
#      16                 draw_columns(A[j], x, y+j*hight, size_x, hight)
#
# /home/campaign/anaconda/lib/python2.7/site-packages/graphics.pyc in draw(self, graphwin)
#     446
#     447         if self.canvas and not self.canvas.isClosed(): raise GraphicsError(OBJ_ALREADY_DRAWN)
# --> 448         if graphwin.isClosed(): raise GraphicsError("Can't draw to closed window")
#     449         self.canvas = graphwin
#     450         self.id = self._draw(graphwin, self.config)
#
# GraphicsError: Can't draw to closed window

# %%
def usual_count_A(x1, y1, x2, y2):
    nr = len(x1)
    nv = len(x2)
    usual_A = np.zeros((nr,nv))
    for i in range (0, nr):
        for j in range (0, nv):
            lenght = ((x1[i]-x2[j])**2+(y1[i]-y2[j])**2)**0.5
            if lenght <> 0:
                usual_A[i][j] = 1/lenght
            else:
                usual_A[i][j] = 0

    return usual_A

# %%
def usual_dot_Ax(A,x):
    usual_f = np.dot(A,x)
        
    return usual_f

# %%
def norm_ff(f1, f2):
    norm_between_f = 0.
    norm_f = 0.
    for i in range (0,nr):
        norm_between_f = norm_between_f+(abs(f1[i]-f2[i]))**2
        norm_f = (norm_f+f2[i]**2)**0.5
    norm_between_f = (norm_between_f**0.5)/norm_f
    return norm_between_f

# %%
np.size(x), np.size(x_new)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-183-c6d94a803856> in <module>()
# ----> 1 np.size(x), np.size(x_new)
#
# NameError: name 'x_new' is not defined

# %%
usual_A = usual_count_A(x1,y1,x2,y2)
usual_A
# Out:
# array([[ 2.54573227,  1.29622511],
#        [ 3.30830861,  1.24898604]])

# %%
t = datetime.today()
usual_A = usual_count_A(x1,y1,x2,y2)
usual_f = usual_dot_Ax(usual_A,x)
f = final_dot(x)
norm_between_f = norm_ff(usual_f, f)
print datetime.today()-t
print norm_between_f
print size(f)
# Out:
# 1000
# 0:00:07.128506
# 2.05524067069e-14
# 1000

# %%
import sys

def show_sizeof(x, level=0):

    #print "\t" * level, x.__class__, sys.getsizeof(x), x
    res = sys.getsizeof(x)
    if hasattr(x, '__iter__'):
        if hasattr(x, 'items'):
            for xx in x.items():
                res += show_sizeof(xx, level + 1)
        else:
            for xx in x:
                res += show_sizeof(xx, level + 1)
    return res

# %%
show_sizeof(A), show_sizeof(usual_A)
# Out:
# (58275992, 24080080)

# %%
import math
import pylab
from matplotlib import mlab
import matplotlib.pyplot as plt

def character_of_A(n):
    
    def final_dot (x):
        x_new = []
        f_true = []
        for i in range(0,nv):
            x_new.append(x[V.data[i]])

        f = dot_Mx(A,x_new,0)

        for i in range (0, nr):
            f_true.append(0)
        for i in range (0, nr):
            f_true[R.data[i]] = f[0][i]

        print size(x_new)

        return f_true
    
    
    global nr 
    global nv 
    global x1
    global y1
    global x2
    global y2
    nr = n
    nv = n
    x1=[]
    y1=[]
    x2=[]
    y2=[]
    for i in range (0,nr):
        x1.append(random.uniform(0,1))
        y1.append(random.uniform(0,1))
    for i in range (0,nv):
        x2.append(random.uniform(0,1))
        y2.append(random.uniform(0,1))

#    x2 = x1
#    y2 = y1
    
    x=[]

    for i in range (0,nv):
        x.append(i)
        
    n_r  = []
    n_v  = []
    for i in range (0,nr):
        n_r.append(i)
    for i in range (0,nv):
        n_v.append(i)


    R = tree(n_r,[0,nr, None, None])
    V = tree(n_v,[0,nv, None, None])
    pre_count_A(R,V)
    A = count_A(R,V)
    usual_A = usual_count_A(x1,y1,x2,y2)
#    print [show_sizeof(A),show_sizeof(usual_A)]
    usual_f = usual_dot_Ax(usual_A,x)
    f = final_dot(x)
#    norm_between_f = 
    print n, size(x)
    return [show_sizeof(A),show_sizeof(usual_A), norm_ff(usual_f, f)]


print size(x)

log_n_list = []
m = 10
for i in range (1, m+1):
    log_n_list.append(2**i) 
log_n_list1 = log_n_list

#print log_n_list

ylist = [character_of_A(n) for n in log_n_list]

#print ylist[1][0]
#ylist2 = [character_of_A(2**n)[1] for n in log_n_list]


plt.figure(1)
plt.title('Amount of information')
plt.xlabel('log n')
plt.ylabel('Bytes')
plt.plot (log_n_list, [ylist[i][0] for i in range (0,m)])
plt.plot (log_n_list, [ylist[i][1] for i in range (0,m)])
plt.figure(2)
plt.plot (log_n_list, [ylist[i][2] for i in range (0,m)])

#pylab.plot (log_n_list, ylist2)


plt.show()
# Out:
# 1000
# 2
# 2 2
# 4
# 4 4
# 8
# 8 8
# 16
# 16 16
# 32
# 32 32
# 64
# 64 64
# 128
# 128 128
# 256
# 256 256
# 512
# 512 512
# 1024

# %%
len(log_n_list)
# Out:
# 199

# %%
# Out:
# [[0, 1], [2, 3]] 	[0, 1] 	[0, 1]
